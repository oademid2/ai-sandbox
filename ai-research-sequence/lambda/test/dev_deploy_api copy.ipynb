# %%
import sys
import os
import json
from dotenv import load_dotenv
# sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), '..')))
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.append(parent_dir)

load_dotenv()


import lambda_function

def test_lambda_handler(event):
    context = None  # or use a mock context object
    result = lambda_function.lambda_handler(event, context)
    print(result)
    return result

# %%
event = {
    "queryStringParameters":{
        "action": "brainstorm",
        "market_description": "EdTech software for college professors to manage their classrooms."
    }
}

# %%
{
    "queryStringParameters":{
        "action": "brainstorm",
        "formula": "Market Size = Number of College Professors * Percentage of Professors Using EdTech Software * Average Annual Spending per Professor."
    }
}
# Out:
# {'queryStringParameters': {'action': 'brainstorm',
#   'formula': 'Market Size = Number of College Professors * Percentage of Professors Using EdTech Software * Average Annual Spending per Professor.'}}

# %%
res = test_lambda_handler(event)
response = json.loads(res['body'])
brainstorm_formula = response['formulas'][0]
brainstorm_formula
# Out:
# {'queryStringParameters': {'action': 'brainstorm', 'market_description': 'EdTech software for college professors to manage their classrooms.'}} None
# {'statusCode': 200, 'headers': {'Content-Type': 'application/json', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Headers': 'Content-Type,X-Amz-Date,Authorization,X-Api-Key,X-Amz-Security-Token', 'Access-Control-Allow-Methods': 'GET,POST,OPTIONS'}, 'body': '{"formulas": ["Total Professors = Number of Colleges * Average Number of Professors per College", "Interested Professors = Total Professors * Interest Rate", "Market Size = Interested Professors * Average Yearly Spending"]}'}
# 'Total Professors = Number of Colleges * Average Number of Professors per College'

# %%
event["queryStringParameters"]["formula"] = brainstorm_formula
event["queryStringParameters"]["action"] = "decompose"
res = test_lambda_handler(event)
response = json.loads(res['body'])
response
# Out:
# {'queryStringParameters': {'action': 'decompose', 'market_description': 'EdTech software for college professors to manage their classrooms.', 'formula': 'Total Professors = Number of Colleges * Average Number of Professors per College'}} None
# {'statusCode': 200, 'headers': {'Content-Type': 'application/json', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Headers': 'Content-Type,X-Amz-Date,Authorization,X-Api-Key,X-Amz-Security-Token', 'Access-Control-Allow-Methods': 'GET,POST,OPTIONS'}, 'body': '{"components": ["Total Professors", "Number of Colleges", "Average Number of Professors per College"]}'}
# {'components': ['Total Professors',
#   'Number of Colleges',
#   'Average Number of Professors per College']}

# %%
response['components'][0]
# Out:
# 'Total Professors'

# %%
event
# Out:
# {'queryStringParameters': {'action': 'decompose',
#   'market_description': 'EdTech software for college professors to manage their classrooms.',
#   'formula': 'Total Professors = Number of Colleges * Average Number of Professors per College'}}

# %%
res
# Out:
# {'statusCode': 200,
#  'headers': {'Content-Type': 'application/json',
#   'Access-Control-Allow-Origin': '*',
#   'Access-Control-Allow-Headers': 'Content-Type,X-Amz-Date,Authorization,X-Api-Key,X-Amz-Security-Token',
#   'Access-Control-Allow-Methods': 'GET,POST,OPTIONS'},
#  'body': '{"components": ["Total Professors", "Number of Colleges", "Average Number of Professors per College"]}'}

# %%
event["body"]
# Out:
# '{"components": ["Total Professors", "Number of Colleges", "Average Number of Professors per College"]}'

# %%
event["body"] = {}
event["body"]["components"] = response['components']
event["body"] = json.dumps(event["body"])
event["queryStringParameters"]["action"] = "datasource"
res = test_lambda_handler(event)
response2 = json.loads(res['body'])
response2
# Out:
# {'queryStringParameters': {'action': 'datasource', 'market_description': 'EdTech software for college professors to manage their classrooms.', 'formula': 'Total Professors = Number of Colleges * Average Number of Professors per College'}, 'body': '{"components": ["Total Professors", "Number of Colleges", "Average Number of Professors per College"]}'} None
# DEBUG: body type = <class 'str'>
# DEBUG: body content = {"components": ["Total Professors", "Number of Colleges", "Average Number of Professors per College"]}
# [INFO] Components: ['Total Professors', 'Number of Colleges', 'Average Number of Professors per College']
#
# [INFO] Processing component: 'Total Professors' sequentially
# [INFO] Running Exa semantic search for query: Total Professors
# [INFO] Retrieved 8 citations from Exa.
# [INFO] Starting parallel extraction of data points from Exa citations...
# [INFO] Extraction complete. Returning DataFrame.
# [INFO] Completed workflow for component: 'Total Professors'
#
# ...
